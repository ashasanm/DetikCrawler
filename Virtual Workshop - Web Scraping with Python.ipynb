# %% [markdown]
# This Virtual Workshop held by Developer Student Club Universitas Jenderal Achmad Yani Yogyakarta.
# In this virtual workshop, you'll be learn how to collect data from a website using Python.
#
# First of all, You should have knowledge in OOP and make sure you have Python installed on your PC/Laptop.
# Install these libraries:
#  - Pandas
#  - BeautifulSoup4
#  - Requests
# You can install those libraries using 'pip' command 'pip install <library>'
#
#
# Happy Coding!!

# %%
# Import Libraries
from bs4 import BeautifulSoup
import pandas as pd
import json, random, re, requests

# %%
# We are going to take article data from Detik (one of Big Medias in Indonesia)

class Detik():
    
    def __init__(self, topic):
        # assign 'topic' to variable self.topic
        self.topic = # your code goes here
        
        
    def get_urls(self):
        news_links = []
        # get news URL
        for page in range():
            url = "https://www.detik.com/search/searchall?query=" + self.topic + "&siteid=2&sortby=time&page=" + str(page)
            html_page = # code here
            soup = BeautifulSoup(html_page, 'lxml')
            articles = # code here
            
            # insert url to list
            for article in articles:
                urls = # code here
                for url in urls:
                    # code here
                    
        return news_links

    
    def extract_news(self):
        # get news article details from scraped urls
        scraped_info = []
        for news in self.get_urls():
            source = news
            html_page = # code here
            soup = BeautifulSoup(html_page, 'lmxl')
            # check if title, author, date, news div, is not None type
            title = soup.find('h1', class_='detail__title')
            if title is not None:
                title = # code here
                title = # code here
                title = # code here
            
            # author
            author = soup.find('div', class_='detail__author')
            if author is not None:
                author = # code here
            
            # date
            date = soup.find('div', class_='detail__date')
            if date is not None:
                date = # code here\
            
            # news div
            news_div = soup.find_all('div', class_='detail__body-text itp_bodycontent')
            if news_div is not None:
                for i in news_div:
                    news_content = # code here
                    # convert scraped data into dictionary
                    news_data = {
                        "url": source,
                        "judul": title,
                        "penulis": author,
                        "tanggal": date,
                        "isi": news_content
                    }
                    # add dicts into a list
                    scraped_info.append(news_data)
                    
        # save scraped data into csv format
        df = # code here
        # export DataFrame into csv format
        df.to_csv()


# Run the program

topic = # code here
shop = # code here
shop = # code here
